# %% [markdown]
# <a href="https://colab.research.google.com/github/TrevorM1738/CycleGAN-style-stransfer/blob/main/cyclegan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the libraies
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# !pip install tensorflow-addons
# !pip install kaggle
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import numpy as np
# !pip install -q pyyaml h5py
import os
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

AUTOTUNE = tf.data.experimental.AUTOTUNE
    
print(tf.__version__)
# Out:
# Collecting tensorflow-addons
#   Downloading https://files.pythonhosted.org/packages/74/e3/56d2fe76f0bb7c88ed9b2a6a557e25e83e252aec08f13de34369cd850a0b/tensorflow_addons-0.12.1-cp37-cp37m-manylinux2010_x86_64.whl (703kB)
#      |████████████████████████████████| 706kB 16.2MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.12.1
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Number of replicas: 1
# 2.4.1

# %% [markdown]
# Loading the data sets from my google drive

# %%
MONET_FILENAMES = tf.io.gfile.glob('/content/drive/MyDrive/gan-getting-started/monet_tfrec/*.tfrec')
print('Monet TFRecord Files:', len(MONET_FILENAMES))

PHOTO_FILENAMES = tf.io.gfile.glob('/content/drive/MyDrive/gan-getting-started/photo_tfrec/*.tfrec')
print('Photo TFRecord Files:', len(PHOTO_FILENAMES))
# Out:
# Monet TFRecord Files: 5
# Photo TFRecord Files: 20

# %%
#resize the images 
IMAGE_SIZE = [256, 256]

def decode_image(image):
  #decoding jpeg withn image and three channels for rgb
    image = tf.image.decode_jpeg(image, channels=3)
  #rescaling the image bewtween -1 and 1
    image = (tf.cast(image, tf.float32) / 127.5) - 1
  #reshaping the image 
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example):
    #formating the tf 
    tfrecord_format = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    return image

# %%
#loading data set 
def load_dataset(filenames, labeled=True, ordered=False):
    #data set variables
    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTOTUNE)
    return dataset

# %%
#loading monet and photo datasets
monet_ds = load_dataset(MONET_FILENAMES, labeled=True).batch(1)
photo_ds = load_dataset(PHOTO_FILENAMES, labeled=True).batch(1)

# %%
example_monet = next(iter(monet_ds))
example_photo = next(iter(photo_ds))

# %%
#print out two example photos
plt.subplot(121)
plt.title('Photo')
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('Monet')
plt.imshow(example_monet[0] * 0.5 + 0.5)

# %%
OUTPUT_CHANNELS = 3
#adds layers for down sampling

def downsample(filters, size, apply_instancenorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

    if apply_instancenorm:
        result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    result.add(layers.LeakyReLU())

    return result

# %%
#adds layers for upsampling
def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2DTranspose(filters, size, strides=2,
                                      padding='same',
                                      kernel_initializer=initializer,
                                      use_bias=False))

    result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    if apply_dropout:
        result.add(layers.Dropout(0.5))

    result.add(layers.ReLU())

    return result

# %%
#creates our gennorators 
def Generator():
    inputs = layers.Input(shape=[256,256,3])

    # bs = batch size
    down_stack = [
        downsample(64, 4, apply_instancenorm=False), # (bs, 128, 128, 64)
        downsample(128, 4), # (bs, 64, 64, 128)
        downsample(256, 4), # (bs, 32, 32, 256)
        downsample(512, 4), # (bs, 16, 16, 512)
        downsample(512, 4), # (bs, 8, 8, 512)
        downsample(512, 4), # (bs, 4, 4, 512)
        downsample(512, 4), # (bs, 2, 2, 512)
        downsample(512, 4), # (bs, 1, 1, 512)
    ]

    up_stack = [
        upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4), # (bs, 16, 16, 1024)
        upsample(256, 4), # (bs, 32, 32, 512)
        upsample(128, 4), # (bs, 64, 64, 256)
        upsample(64, 4), # (bs, 128, 128, 128)
    ]

    initializer = tf.random_normal_initializer(0., 0.02)
    last = layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                  strides=2,
                                  padding='same',
                                  kernel_initializer=initializer,
                                  activation='tanh') # (bs, 256, 256, 3)
    x = inputs

    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])

    x = last(x)

    return keras.Model(inputs=inputs, outputs=x)

# %%
#creates layers for or discrimiator
def Discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    inp = layers.Input(shape=[256, 256, 3], name='input_image')

    x = inp

    down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

    zero_pad1 = layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = layers.Conv2D(512, 4, strides=1,
                         kernel_initializer=initializer,
                         use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

    norm1 = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(conv)

    leaky_relu = layers.LeakyReLU()(norm1)

    zero_pad2 = layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

    last = layers.Conv2D(1, 4, strides=1,
                         kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

    return tf.keras.Model(inputs=inp, outputs=last)

# %%
#makes all foutr of the models

with strategy.scope():
    monet_generator = Generator() # transforms photos to Monet-esque paintings
    photo_generator = Generator() # transforms Monet paintings to be more like photos

    monet_discriminator = Discriminator() # differentiates real Monet paintings and generated Monet paintings
    photo_discriminator = Discriminator() # differentiates real photos and generated photos

# %%
to_monet = monet_generator(example_photo)

plt.subplot(1, 2, 1)
plt.title("Original Photo")
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(1, 2, 2)
plt.title("Monet style Photo")
plt.imshow(to_monet[0] * 0.5 + 0.5)
plt.show()

# %% [markdown]
# We will subclass a tf.keras.Model so that we can run fit() later to train our model. During the training step, the model transforms a photo to a Monet painting and then back to a photo. The difference between the original photo and the twice-transformed photo is the cycle-consistency loss. We want the original photo and the twice-transformed photo to be similar to one another

# %%
#creating a class for the cycleGAN model
class CycleGan(keras.Model):
    #pulling in the genorators and discriminators
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn
        
    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
        
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)

            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)

        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        
        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %% [markdown]
# The discriminator loss function below compares real images to a matrix of 1s and fake images to a matrix of 0s. The perfect discriminator will output all 1s for real images and all 0s for fake images. The discriminator loss outputs the average of the real and generated loss.

# %%
with strategy.scope():
    def discriminator_loss(real, generated):
        real_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(real), real)

        generated_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.zeros_like(generated), generated)

        total_disc_loss = real_loss + generated_loss

        return total_disc_loss * 0.5

# %% [markdown]
# The generator wants to fool the discriminator into thinking the generated image is real. The perfect generator will have the discriminator output only 1s. Thus, it compares the generated image to a matrix of 1s to find the loss.

# %%
with strategy.scope():
    #loss for genorator
    def generator_loss(generated):
        return tf.keras.losses.BinaryCrossentropy(from_logits=True, 
        reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(generated), generated)

# %% [markdown]
# We want our original photo and the twice transformed photo to be similar to one another. Thus, we can calculate the cycle consistency loss be finding the average of their difference.

# %%
with strategy.scope():
    #loss for cycle
    def calc_cycle_loss(real_image, cycled_image, LAMBDA):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

        return LAMBDA * loss1

# %% [markdown]
# The identity loss compares the image with its generator (i.e. photo with photo generator). If given a photo as input, we want it to generate the same image as the image was originally a photo. The identity loss compares the input with the output of the generator.

# %%
with strategy.scope():
    #identity loss
    def identity_loss(real_image, same_image, LAMBDA):
        loss = tf.reduce_mean(tf.abs(real_image - same_image))
        return LAMBDA * 0.5 * loss

# %%
with strategy.scope():
    #Optimizers
    monet_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

    monet_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
with strategy.scope():
    #putting it all together 
    cycle_gan_model = CycleGan(
        monet_generator, photo_generator, monet_discriminator, photo_discriminator
    )

    cycle_gan_model.compile(
        m_gen_optimizer = monet_generator_optimizer,
        p_gen_optimizer = photo_generator_optimizer,
        m_disc_optimizer = monet_discriminator_optimizer,
        p_disc_optimizer = photo_discriminator_optimizer,
        gen_loss_fn = generator_loss,
        disc_loss_fn = discriminator_loss,
        cycle_loss_fn = calc_cycle_loss,
        identity_loss_fn = identity_loss
    )

# %%
#saving the model
checkpoint_path = "/content/drive/MyDrive/model"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
#fitting the model
cycle_gan_model.fit(
    tf.data.Dataset.zip((monet_ds, photo_ds)),
    epochs=250,
)
# Out:
# Epoch 1/250
# 300/300 [==============================] - 97s 183ms/step - monet_gen_loss: 5.2868 - photo_gen_loss: 5.5394 - monet_disc_loss: 0.6441 - photo_disc_loss: 0.5588
# Epoch 2/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.6486 - photo_gen_loss: 3.7315 - monet_disc_loss: 0.6546 - photo_disc_loss: 0.6690
# Epoch 3/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.5824 - photo_gen_loss: 3.6625 - monet_disc_loss: 0.6354 - photo_disc_loss: 0.6281
# Epoch 4/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.4691 - photo_gen_loss: 3.5461 - monet_disc_loss: 0.6322 - photo_disc_loss: 0.6262
# Epoch 5/250
# 300/300 [==============================] - 54s 181ms/step - monet_gen_loss: 3.3147 - photo_gen_loss: 3.3586 - monet_disc_loss: 0.6220 - photo_disc_loss: 0.6239
# Epoch 6/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.1978 - photo_gen_loss: 3.2287 - monet_disc_loss: 0.6170 - photo_disc_loss: 0.6120
# Epoch 7/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.1939 - photo_gen_loss: 3.2069 - monet_disc_loss: 0.6053 - photo_disc_loss: 0.6008
# Epoch 8/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.1862 - photo_gen_loss: 3.2306 - monet_disc_loss: 0.6119 - photo_disc_loss: 0.5953
# Epoch 9/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.1690 - photo_gen_loss: 3.2179 - monet_disc_loss: 0.6093 - photo_disc_loss: 0.5987
# Epoch 10/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.1760 - photo_gen_loss: 3.2416 - monet_disc_loss: 0.6090 - photo_disc_loss: 0.6062
# Epoch 11/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.1369 - photo_gen_loss: 3.1843 - monet_disc_loss: 0.6070 - photo_disc_loss: 0.6073
# Epoch 12/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.1024 - photo_gen_loss: 3.1572 - monet_disc_loss: 0.6084 - photo_disc_loss: 0.6061
# Epoch 13/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.0618 - photo_gen_loss: 3.1401 - monet_disc_loss: 0.6146 - photo_disc_loss: 0.5992
# Epoch 14/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0212 - photo_gen_loss: 3.1113 - monet_disc_loss: 0.6173 - photo_disc_loss: 0.6012
# Epoch 15/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9774 - photo_gen_loss: 3.0661 - monet_disc_loss: 0.6160 - photo_disc_loss: 0.6024
# Epoch 16/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9412 - photo_gen_loss: 3.0366 - monet_disc_loss: 0.6145 - photo_disc_loss: 0.5989
# Epoch 17/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.9120 - photo_gen_loss: 3.0144 - monet_disc_loss: 0.6156 - photo_disc_loss: 0.5982
# Epoch 18/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.8936 - photo_gen_loss: 3.0030 - monet_disc_loss: 0.6154 - photo_disc_loss: 0.5980
# Epoch 19/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8700 - photo_gen_loss: 2.9779 - monet_disc_loss: 0.6182 - photo_disc_loss: 0.6026
# Epoch 20/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8464 - photo_gen_loss: 2.9454 - monet_disc_loss: 0.6168 - photo_disc_loss: 0.6043
# Epoch 21/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8304 - photo_gen_loss: 2.9256 - monet_disc_loss: 0.6188 - photo_disc_loss: 0.6063
# Epoch 22/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.8050 - photo_gen_loss: 2.8989 - monet_disc_loss: 0.6210 - photo_disc_loss: 0.6071
# Epoch 23/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.7869 - photo_gen_loss: 2.8782 - monet_disc_loss: 0.6221 - photo_disc_loss: 0.6073
# Epoch 24/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.7611 - photo_gen_loss: 2.8480 - monet_disc_loss: 0.6219 - photo_disc_loss: 0.6087
# Epoch 25/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.7415 - photo_gen_loss: 2.8255 - monet_disc_loss: 0.6241 - photo_disc_loss: 0.6124
# Epoch 26/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.7172 - photo_gen_loss: 2.8028 - monet_disc_loss: 0.6242 - photo_disc_loss: 0.6165
# Epoch 27/250
# 300/300 [==============================] - 54s 181ms/step - monet_gen_loss: 2.7058 - photo_gen_loss: 2.8054 - monet_disc_loss: 0.6238 - photo_disc_loss: 0.6083
# Epoch 28/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.6535 - photo_gen_loss: 2.7628 - monet_disc_loss: 0.6277 - photo_disc_loss: 0.6165
# Epoch 29/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.6687 - photo_gen_loss: 2.7633 - monet_disc_loss: 0.6247 - photo_disc_loss: 0.6127
# Epoch 30/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.6803 - photo_gen_loss: 2.7752 - monet_disc_loss: 0.6183 - photo_disc_loss: 0.6095
# Epoch 31/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.6588 - photo_gen_loss: 2.7254 - monet_disc_loss: 0.6210 - photo_disc_loss: 0.6145
# Epoch 32/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.5879 - photo_gen_loss: 2.6952 - monet_disc_loss: 0.6284 - photo_disc_loss: 0.6114
# Epoch 33/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.7221 - photo_gen_loss: 2.8221 - monet_disc_loss: 0.6109 - photo_disc_loss: 0.5920
# Epoch 34/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.6494 - photo_gen_loss: 2.7632 - monet_disc_loss: 0.6214 - photo_disc_loss: 0.6075
# Epoch 35/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.7607 - photo_gen_loss: 2.8821 - monet_disc_loss: 0.5873 - photo_disc_loss: 0.5581
# Epoch 36/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.7554 - photo_gen_loss: 2.9350 - monet_disc_loss: 0.6053 - photo_disc_loss: 0.5664
# Epoch 37/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8079 - photo_gen_loss: 3.0140 - monet_disc_loss: 0.6028 - photo_disc_loss: 0.5616
# Epoch 38/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.6846 - photo_gen_loss: 2.8369 - monet_disc_loss: 0.6169 - photo_disc_loss: 0.5962
# Epoch 39/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.7697 - photo_gen_loss: 2.9470 - monet_disc_loss: 0.5949 - photo_disc_loss: 0.5556
# Epoch 40/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.6586 - photo_gen_loss: 2.8122 - monet_disc_loss: 0.6169 - photo_disc_loss: 0.5930
# Epoch 41/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.6134 - photo_gen_loss: 2.7317 - monet_disc_loss: 0.6045 - photo_disc_loss: 0.5878
# Epoch 42/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.7522 - photo_gen_loss: 2.9316 - monet_disc_loss: 0.5951 - photo_disc_loss: 0.5556
# Epoch 43/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.8214 - photo_gen_loss: 2.9430 - monet_disc_loss: 0.5829 - photo_disc_loss: 0.5634
# Epoch 44/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.6506 - photo_gen_loss: 2.7887 - monet_disc_loss: 0.5987 - photo_disc_loss: 0.5780
# Epoch 45/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.6313 - photo_gen_loss: 2.8011 - monet_disc_loss: 0.6052 - photo_disc_loss: 0.5701
# Epoch 46/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.6646 - photo_gen_loss: 2.8218 - monet_disc_loss: 0.6015 - photo_disc_loss: 0.5694
# Epoch 47/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 2.9946 - photo_gen_loss: 3.0709 - monet_disc_loss: 0.5162 - photo_disc_loss: 0.4928
# Epoch 48/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9025 - photo_gen_loss: 3.0370 - monet_disc_loss: 0.6022 - photo_disc_loss: 0.5627
# Epoch 49/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8435 - photo_gen_loss: 2.9451 - monet_disc_loss: 0.5765 - photo_disc_loss: 0.5604
# Epoch 50/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8299 - photo_gen_loss: 2.9603 - monet_disc_loss: 0.5740 - photo_disc_loss: 0.5453
# Epoch 51/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8863 - photo_gen_loss: 3.1287 - monet_disc_loss: 0.5780 - photo_disc_loss: 0.5209
# Epoch 52/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.8247 - photo_gen_loss: 3.0406 - monet_disc_loss: 0.5729 - photo_disc_loss: 0.5180
# Epoch 53/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0442 - photo_gen_loss: 3.1453 - monet_disc_loss: 0.5141 - photo_disc_loss: 0.4719
# Epoch 54/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.2531 - photo_gen_loss: 3.2820 - monet_disc_loss: 0.5402 - photo_disc_loss: 0.5186
# Epoch 55/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8903 - photo_gen_loss: 3.0724 - monet_disc_loss: 0.5840 - photo_disc_loss: 0.5397
# Epoch 56/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0350 - photo_gen_loss: 3.2125 - monet_disc_loss: 0.5465 - photo_disc_loss: 0.5162
# Epoch 57/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0087 - photo_gen_loss: 3.1249 - monet_disc_loss: 0.5502 - photo_disc_loss: 0.5142
# Epoch 58/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0134 - photo_gen_loss: 3.1430 - monet_disc_loss: 0.5501 - photo_disc_loss: 0.5271
# Epoch 59/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9156 - photo_gen_loss: 3.0526 - monet_disc_loss: 0.5654 - photo_disc_loss: 0.5414
# Epoch 60/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8882 - photo_gen_loss: 3.0087 - monet_disc_loss: 0.5695 - photo_disc_loss: 0.5459
# Epoch 61/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8892 - photo_gen_loss: 3.0095 - monet_disc_loss: 0.5558 - photo_disc_loss: 0.5393
# Epoch 62/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9534 - photo_gen_loss: 3.0450 - monet_disc_loss: 0.5570 - photo_disc_loss: 0.5363
# Epoch 63/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0808 - photo_gen_loss: 3.1886 - monet_disc_loss: 0.5406 - photo_disc_loss: 0.5144
# Epoch 64/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0609 - photo_gen_loss: 3.2445 - monet_disc_loss: 0.5399 - photo_disc_loss: 0.4946
# Epoch 65/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.1464 - photo_gen_loss: 3.4098 - monet_disc_loss: 0.5335 - photo_disc_loss: 0.4790
# Epoch 66/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9720 - photo_gen_loss: 3.1456 - monet_disc_loss: 0.5565 - photo_disc_loss: 0.5250
# Epoch 67/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.8781 - photo_gen_loss: 3.0657 - monet_disc_loss: 0.5632 - photo_disc_loss: 0.5341
# Epoch 68/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.8245 - photo_gen_loss: 2.9891 - monet_disc_loss: 0.5685 - photo_disc_loss: 0.5404
# Epoch 69/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.8257 - photo_gen_loss: 2.9892 - monet_disc_loss: 0.5699 - photo_disc_loss: 0.5382
# Epoch 70/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.8210 - photo_gen_loss: 2.9818 - monet_disc_loss: 0.5692 - photo_disc_loss: 0.5432
# Epoch 71/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8359 - photo_gen_loss: 2.9918 - monet_disc_loss: 0.5683 - photo_disc_loss: 0.5396
# Epoch 72/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8131 - photo_gen_loss: 2.9590 - monet_disc_loss: 0.5712 - photo_disc_loss: 0.5443
# Epoch 73/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0319 - photo_gen_loss: 3.0818 - monet_disc_loss: 0.5396 - photo_disc_loss: 0.5424
# Epoch 74/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0067 - photo_gen_loss: 3.0932 - monet_disc_loss: 0.5512 - photo_disc_loss: 0.5277
# Epoch 75/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9218 - photo_gen_loss: 3.0521 - monet_disc_loss: 0.5538 - photo_disc_loss: 0.5319
# Epoch 76/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8919 - photo_gen_loss: 3.0426 - monet_disc_loss: 0.5617 - photo_disc_loss: 0.5413
# Epoch 77/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8807 - photo_gen_loss: 2.9777 - monet_disc_loss: 0.5555 - photo_disc_loss: 0.5465
# Epoch 78/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0382 - photo_gen_loss: 3.2254 - monet_disc_loss: 0.5464 - photo_disc_loss: 0.5011
# Epoch 79/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9348 - photo_gen_loss: 3.1191 - monet_disc_loss: 0.5564 - photo_disc_loss: 0.5192
# Epoch 80/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.8397 - photo_gen_loss: 2.9947 - monet_disc_loss: 0.5687 - photo_disc_loss: 0.5438
# Epoch 81/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.8504 - photo_gen_loss: 3.0083 - monet_disc_loss: 0.5663 - photo_disc_loss: 0.5372
# Epoch 82/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.8112 - photo_gen_loss: 2.9583 - monet_disc_loss: 0.5759 - photo_disc_loss: 0.5464
# Epoch 83/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.1737 - photo_gen_loss: 3.2982 - monet_disc_loss: 0.5308 - photo_disc_loss: 0.4819
# Epoch 84/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9089 - photo_gen_loss: 3.0665 - monet_disc_loss: 0.5607 - photo_disc_loss: 0.5224
# Epoch 85/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9018 - photo_gen_loss: 3.0178 - monet_disc_loss: 0.5623 - photo_disc_loss: 0.5433
# Epoch 86/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0799 - photo_gen_loss: 3.2230 - monet_disc_loss: 0.5403 - photo_disc_loss: 0.5061
# Epoch 87/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0739 - photo_gen_loss: 3.2075 - monet_disc_loss: 0.5292 - photo_disc_loss: 0.5024
# Epoch 88/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.4737 - photo_gen_loss: 3.3538 - monet_disc_loss: 0.4657 - photo_disc_loss: 0.4774
# Epoch 89/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.4239 - photo_gen_loss: 3.3216 - monet_disc_loss: 0.4794 - photo_disc_loss: 0.4987
# Epoch 90/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.4794 - photo_gen_loss: 3.3022 - monet_disc_loss: 0.4739 - photo_disc_loss: 0.5022
# Epoch 91/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.5248 - photo_gen_loss: 3.3933 - monet_disc_loss: 0.4775 - photo_disc_loss: 0.4925
# Epoch 92/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.3572 - photo_gen_loss: 3.2913 - monet_disc_loss: 0.4995 - photo_disc_loss: 0.4997
# Epoch 93/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.3220 - photo_gen_loss: 3.3363 - monet_disc_loss: 0.5016 - photo_disc_loss: 0.5046
# Epoch 94/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.1498 - photo_gen_loss: 3.1940 - monet_disc_loss: 0.5217 - photo_disc_loss: 0.5206
# Epoch 95/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.0323 - photo_gen_loss: 3.1004 - monet_disc_loss: 0.5324 - photo_disc_loss: 0.5293
# Epoch 96/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.1187 - photo_gen_loss: 3.1225 - monet_disc_loss: 0.5278 - photo_disc_loss: 0.5294
# Epoch 97/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1059 - photo_gen_loss: 3.1550 - monet_disc_loss: 0.5293 - photo_disc_loss: 0.5192
# Epoch 98/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0080 - photo_gen_loss: 3.0804 - monet_disc_loss: 0.5357 - photo_disc_loss: 0.5342
# Epoch 99/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0202 - photo_gen_loss: 3.0668 - monet_disc_loss: 0.5408 - photo_disc_loss: 0.5482
# Epoch 100/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.1005 - photo_gen_loss: 3.3000 - monet_disc_loss: 0.5339 - photo_disc_loss: 0.4852
# Epoch 101/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0822 - photo_gen_loss: 3.2981 - monet_disc_loss: 0.5361 - photo_disc_loss: 0.4905
# Epoch 102/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0990 - photo_gen_loss: 3.1880 - monet_disc_loss: 0.5430 - photo_disc_loss: 0.5335
# Epoch 103/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.4040 - photo_gen_loss: 3.3300 - monet_disc_loss: 0.4730 - photo_disc_loss: 0.4991
# Epoch 104/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.2479 - photo_gen_loss: 3.2263 - monet_disc_loss: 0.5007 - photo_disc_loss: 0.5296
# Epoch 105/250
# 300/300 [==============================] - 55s 182ms/step - monet_gen_loss: 3.0986 - photo_gen_loss: 3.0925 - monet_disc_loss: 0.5335 - photo_disc_loss: 0.5458
# Epoch 106/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0368 - photo_gen_loss: 3.0461 - monet_disc_loss: 0.5454 - photo_disc_loss: 0.5504
# Epoch 107/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0234 - photo_gen_loss: 3.0391 - monet_disc_loss: 0.5396 - photo_disc_loss: 0.5519
# Epoch 108/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0227 - photo_gen_loss: 3.0601 - monet_disc_loss: 0.5521 - photo_disc_loss: 0.5543
# Epoch 109/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.5769 - photo_gen_loss: 3.5726 - monet_disc_loss: 0.4612 - photo_disc_loss: 0.4431
# Epoch 110/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.6271 - photo_gen_loss: 3.5168 - monet_disc_loss: 0.4598 - photo_disc_loss: 0.4781
# Epoch 111/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.2207 - photo_gen_loss: 3.2031 - monet_disc_loss: 0.5157 - photo_disc_loss: 0.5373
# Epoch 112/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.1089 - photo_gen_loss: 3.1010 - monet_disc_loss: 0.5347 - photo_disc_loss: 0.5597
# Epoch 113/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1007 - photo_gen_loss: 3.0762 - monet_disc_loss: 0.5437 - photo_disc_loss: 0.5505
# Epoch 114/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0723 - photo_gen_loss: 3.0694 - monet_disc_loss: 0.5463 - photo_disc_loss: 0.5556
# Epoch 115/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0708 - photo_gen_loss: 3.1499 - monet_disc_loss: 0.5519 - photo_disc_loss: 0.5249
# Epoch 116/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0307 - photo_gen_loss: 3.0678 - monet_disc_loss: 0.5523 - photo_disc_loss: 0.5562
# Epoch 117/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0210 - photo_gen_loss: 3.0376 - monet_disc_loss: 0.5561 - photo_disc_loss: 0.5640
# Epoch 118/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0117 - photo_gen_loss: 3.0241 - monet_disc_loss: 0.5617 - photo_disc_loss: 0.5706
# Epoch 119/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0277 - photo_gen_loss: 3.0304 - monet_disc_loss: 0.5662 - photo_disc_loss: 0.5635
# Epoch 120/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0115 - photo_gen_loss: 3.0158 - monet_disc_loss: 0.5728 - photo_disc_loss: 0.5631
# Epoch 121/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9693 - photo_gen_loss: 2.9886 - monet_disc_loss: 0.5645 - photo_disc_loss: 0.5749
# Epoch 122/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0879 - photo_gen_loss: 3.0411 - monet_disc_loss: 0.5483 - photo_disc_loss: 0.5689
# Epoch 123/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1265 - photo_gen_loss: 3.1218 - monet_disc_loss: 0.5439 - photo_disc_loss: 0.5331
# Epoch 124/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.9455 - photo_gen_loss: 3.5841 - monet_disc_loss: 0.3851 - photo_disc_loss: 0.4261
# Epoch 125/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.6875 - photo_gen_loss: 3.5230 - monet_disc_loss: 0.4345 - photo_disc_loss: 0.4659
# Epoch 126/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.4909 - photo_gen_loss: 3.4319 - monet_disc_loss: 0.4802 - photo_disc_loss: 0.4793
# Epoch 127/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.3810 - photo_gen_loss: 3.2853 - monet_disc_loss: 0.4911 - photo_disc_loss: 0.5245
# Epoch 128/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.2749 - photo_gen_loss: 3.1944 - monet_disc_loss: 0.5242 - photo_disc_loss: 0.5252
# Epoch 129/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1334 - photo_gen_loss: 3.1017 - monet_disc_loss: 0.5328 - photo_disc_loss: 0.5521
# Epoch 130/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1050 - photo_gen_loss: 3.0603 - monet_disc_loss: 0.5422 - photo_disc_loss: 0.5424
# Epoch 131/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0714 - photo_gen_loss: 3.0431 - monet_disc_loss: 0.5483 - photo_disc_loss: 0.5564
# Epoch 132/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0336 - photo_gen_loss: 3.0238 - monet_disc_loss: 0.5526 - photo_disc_loss: 0.5570
# Epoch 133/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0405 - photo_gen_loss: 3.0433 - monet_disc_loss: 0.5601 - photo_disc_loss: 0.5657
# Epoch 134/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0430 - photo_gen_loss: 3.0658 - monet_disc_loss: 0.5635 - photo_disc_loss: 0.5431
# Epoch 135/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0111 - photo_gen_loss: 3.0270 - monet_disc_loss: 0.5648 - photo_disc_loss: 0.5567
# Epoch 136/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0265 - photo_gen_loss: 3.0449 - monet_disc_loss: 0.5650 - photo_disc_loss: 0.5585
# Epoch 137/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0063 - photo_gen_loss: 3.0345 - monet_disc_loss: 0.5684 - photo_disc_loss: 0.5652
# Epoch 138/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0119 - photo_gen_loss: 3.0193 - monet_disc_loss: 0.5654 - photo_disc_loss: 0.5721
# Epoch 139/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0132 - photo_gen_loss: 3.0069 - monet_disc_loss: 0.5691 - photo_disc_loss: 0.5646
# Epoch 140/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0107 - photo_gen_loss: 3.0090 - monet_disc_loss: 0.5725 - photo_disc_loss: 0.5626
# Epoch 141/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9760 - photo_gen_loss: 2.9912 - monet_disc_loss: 0.5731 - photo_disc_loss: 0.5647
# Epoch 142/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.3518 - photo_gen_loss: 3.2750 - monet_disc_loss: 0.4986 - photo_disc_loss: 0.5191
# Epoch 143/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 3.0455 - photo_gen_loss: 3.0639 - monet_disc_loss: 0.5661 - photo_disc_loss: 0.5520
# Epoch 144/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9915 - photo_gen_loss: 2.9696 - monet_disc_loss: 0.5693 - photo_disc_loss: 0.5803
# Epoch 145/250
# 300/300 [==============================] - 55s 183ms/step - monet_gen_loss: 2.9445 - photo_gen_loss: 2.9410 - monet_disc_loss: 0.5807 - photo_disc_loss: 0.5796
# Epoch 146/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9606 - photo_gen_loss: 2.9903 - monet_disc_loss: 0.5845 - photo_disc_loss: 0.5514
# Epoch 147/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1889 - photo_gen_loss: 3.1656 - monet_disc_loss: 0.5189 - photo_disc_loss: 0.5162
# Epoch 148/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1155 - photo_gen_loss: 3.1415 - monet_disc_loss: 0.5401 - photo_disc_loss: 0.5358
# Epoch 149/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0643 - photo_gen_loss: 3.0485 - monet_disc_loss: 0.5576 - photo_disc_loss: 0.5741
# Epoch 150/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0212 - photo_gen_loss: 3.0075 - monet_disc_loss: 0.5674 - photo_disc_loss: 0.5704
# Epoch 151/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9709 - photo_gen_loss: 2.9664 - monet_disc_loss: 0.5685 - photo_disc_loss: 0.5699
# Epoch 152/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9694 - photo_gen_loss: 2.9576 - monet_disc_loss: 0.5652 - photo_disc_loss: 0.5750
# Epoch 153/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9751 - photo_gen_loss: 2.9666 - monet_disc_loss: 0.5813 - photo_disc_loss: 0.5661
# Epoch 154/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9887 - photo_gen_loss: 3.0219 - monet_disc_loss: 0.5813 - photo_disc_loss: 0.5504
# Epoch 155/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0376 - photo_gen_loss: 3.0512 - monet_disc_loss: 0.5459 - photo_disc_loss: 0.5555
# Epoch 156/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.2636 - photo_gen_loss: 3.2121 - monet_disc_loss: 0.4981 - photo_disc_loss: 0.5095
# Epoch 157/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0159 - photo_gen_loss: 2.9680 - monet_disc_loss: 0.5637 - photo_disc_loss: 0.5691
# Epoch 158/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9310 - photo_gen_loss: 2.9068 - monet_disc_loss: 0.5762 - photo_disc_loss: 0.5841
# Epoch 159/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 2.9511 - photo_gen_loss: 2.9118 - monet_disc_loss: 0.5615 - photo_disc_loss: 0.5752
# Epoch 160/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0990 - photo_gen_loss: 2.9850 - monet_disc_loss: 0.5316 - photo_disc_loss: 0.5603
# Epoch 161/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9588 - photo_gen_loss: 2.9183 - monet_disc_loss: 0.5723 - photo_disc_loss: 0.5715
# Epoch 162/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9308 - photo_gen_loss: 2.9144 - monet_disc_loss: 0.5795 - photo_disc_loss: 0.5782
# Epoch 163/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 2.9358 - photo_gen_loss: 2.9491 - monet_disc_loss: 0.5789 - photo_disc_loss: 0.5670
# Epoch 164/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 2.9121 - photo_gen_loss: 2.9143 - monet_disc_loss: 0.5769 - photo_disc_loss: 0.5633
# Epoch 165/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9203 - photo_gen_loss: 2.9134 - monet_disc_loss: 0.5755 - photo_disc_loss: 0.5835
# Epoch 166/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 2.9411 - photo_gen_loss: 2.9262 - monet_disc_loss: 0.5726 - photo_disc_loss: 0.5768
# Epoch 167/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9467 - photo_gen_loss: 2.9028 - monet_disc_loss: 0.5700 - photo_disc_loss: 0.5790
# Epoch 168/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9118 - photo_gen_loss: 2.8822 - monet_disc_loss: 0.5855 - photo_disc_loss: 0.5708
# Epoch 169/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9352 - photo_gen_loss: 2.9178 - monet_disc_loss: 0.5675 - photo_disc_loss: 0.5759
# Epoch 170/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 2.9326 - photo_gen_loss: 2.8819 - monet_disc_loss: 0.5601 - photo_disc_loss: 0.5682
# Epoch 171/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 2.9697 - photo_gen_loss: 2.9091 - monet_disc_loss: 0.5557 - photo_disc_loss: 0.5756
# Epoch 172/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 2.9188 - photo_gen_loss: 2.8678 - monet_disc_loss: 0.5790 - photo_disc_loss: 0.5846
# Epoch 173/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 2.8758 - photo_gen_loss: 2.8361 - monet_disc_loss: 0.5753 - photo_disc_loss: 0.5812
# Epoch 174/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 2.8776 - photo_gen_loss: 2.8553 - monet_disc_loss: 0.5756 - photo_disc_loss: 0.5858
# Epoch 175/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 2.8770 - photo_gen_loss: 2.8490 - monet_disc_loss: 0.5783 - photo_disc_loss: 0.5900
# Epoch 176/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 2.8904 - photo_gen_loss: 2.8489 - monet_disc_loss: 0.5720 - photo_disc_loss: 0.5764
# Epoch 177/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 2.9137 - photo_gen_loss: 2.8570 - monet_disc_loss: 0.5722 - photo_disc_loss: 0.5816
# Epoch 178/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 2.9643 - photo_gen_loss: 2.8914 - monet_disc_loss: 0.5553 - photo_disc_loss: 0.5657
# Epoch 179/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.0672 - photo_gen_loss: 3.1411 - monet_disc_loss: 0.5527 - photo_disc_loss: 0.4896
# Epoch 180/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 2.9331 - photo_gen_loss: 2.9757 - monet_disc_loss: 0.5655 - photo_disc_loss: 0.5431
# Epoch 181/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 2.8892 - photo_gen_loss: 2.8533 - monet_disc_loss: 0.5618 - photo_disc_loss: 0.5756
# Epoch 182/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 2.9085 - photo_gen_loss: 2.8350 - monet_disc_loss: 0.5603 - photo_disc_loss: 0.5740
# Epoch 183/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.0097 - photo_gen_loss: 2.8707 - monet_disc_loss: 0.5471 - photo_disc_loss: 0.5761
# Epoch 184/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 2.9816 - photo_gen_loss: 2.8533 - monet_disc_loss: 0.5417 - photo_disc_loss: 0.5712
# Epoch 185/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.1346 - photo_gen_loss: 3.0675 - monet_disc_loss: 0.5248 - photo_disc_loss: 0.5257
# Epoch 186/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.4354 - photo_gen_loss: 3.6416 - monet_disc_loss: 0.4406 - photo_disc_loss: 0.3574
# Epoch 187/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.2571 - photo_gen_loss: 3.3865 - monet_disc_loss: 0.5060 - photo_disc_loss: 0.4393
# Epoch 188/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1037 - photo_gen_loss: 3.0603 - monet_disc_loss: 0.5158 - photo_disc_loss: 0.5309
# Epoch 189/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.0107 - photo_gen_loss: 2.9513 - monet_disc_loss: 0.5448 - photo_disc_loss: 0.5683
# Epoch 190/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 2.9244 - photo_gen_loss: 2.8872 - monet_disc_loss: 0.5710 - photo_disc_loss: 0.5644
# Epoch 191/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 2.9640 - photo_gen_loss: 2.8978 - monet_disc_loss: 0.5412 - photo_disc_loss: 0.5575
# Epoch 192/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 2.9959 - photo_gen_loss: 2.8975 - monet_disc_loss: 0.5516 - photo_disc_loss: 0.5533
# Epoch 193/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.0506 - photo_gen_loss: 3.1146 - monet_disc_loss: 0.5300 - photo_disc_loss: 0.4953
# Epoch 194/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.0522 - photo_gen_loss: 3.0279 - monet_disc_loss: 0.5273 - photo_disc_loss: 0.5296
# Epoch 195/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.0374 - photo_gen_loss: 2.9324 - monet_disc_loss: 0.5400 - photo_disc_loss: 0.5714
# Epoch 196/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.0509 - photo_gen_loss: 2.9290 - monet_disc_loss: 0.5365 - photo_disc_loss: 0.5558
# Epoch 197/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0239 - photo_gen_loss: 2.9138 - monet_disc_loss: 0.5380 - photo_disc_loss: 0.5494
# Epoch 198/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 2.9730 - photo_gen_loss: 2.9092 - monet_disc_loss: 0.5590 - photo_disc_loss: 0.5650
# Epoch 199/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0607 - photo_gen_loss: 2.9727 - monet_disc_loss: 0.5210 - photo_disc_loss: 0.5590
# Epoch 200/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1677 - photo_gen_loss: 3.1510 - monet_disc_loss: 0.5158 - photo_disc_loss: 0.5142
# Epoch 201/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.4473 - photo_gen_loss: 3.5536 - monet_disc_loss: 0.4582 - photo_disc_loss: 0.3832
# Epoch 202/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1382 - photo_gen_loss: 3.1967 - monet_disc_loss: 0.5143 - photo_disc_loss: 0.4907
# Epoch 203/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.0320 - photo_gen_loss: 3.0038 - monet_disc_loss: 0.5339 - photo_disc_loss: 0.5557
# Epoch 204/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0619 - photo_gen_loss: 2.9503 - monet_disc_loss: 0.5307 - photo_disc_loss: 0.5479
# Epoch 205/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0078 - photo_gen_loss: 2.9273 - monet_disc_loss: 0.5496 - photo_disc_loss: 0.5595
# Epoch 206/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.0388 - photo_gen_loss: 3.0305 - monet_disc_loss: 0.5401 - photo_disc_loss: 0.5222
# Epoch 207/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.0473 - photo_gen_loss: 2.9779 - monet_disc_loss: 0.5203 - photo_disc_loss: 0.5569
# Epoch 208/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1141 - photo_gen_loss: 2.9811 - monet_disc_loss: 0.5297 - photo_disc_loss: 0.5554
# Epoch 209/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.0661 - photo_gen_loss: 2.9464 - monet_disc_loss: 0.5235 - photo_disc_loss: 0.5487
# Epoch 210/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1514 - photo_gen_loss: 2.9766 - monet_disc_loss: 0.5071 - photo_disc_loss: 0.5536
# Epoch 211/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1673 - photo_gen_loss: 2.9804 - monet_disc_loss: 0.4960 - photo_disc_loss: 0.5538
# Epoch 212/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1517 - photo_gen_loss: 2.9685 - monet_disc_loss: 0.5101 - photo_disc_loss: 0.5516
# Epoch 213/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.1821 - photo_gen_loss: 2.9836 - monet_disc_loss: 0.5020 - photo_disc_loss: 0.5627
# Epoch 214/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.2334 - photo_gen_loss: 2.9799 - monet_disc_loss: 0.4880 - photo_disc_loss: 0.5597
# Epoch 215/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.1329 - photo_gen_loss: 2.9526 - monet_disc_loss: 0.5210 - photo_disc_loss: 0.5565
# Epoch 216/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1200 - photo_gen_loss: 2.9623 - monet_disc_loss: 0.5196 - photo_disc_loss: 0.5685
# Epoch 217/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1248 - photo_gen_loss: 2.9705 - monet_disc_loss: 0.5386 - photo_disc_loss: 0.5563
# Epoch 218/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.6410 - photo_gen_loss: 3.3009 - monet_disc_loss: 0.4014 - photo_disc_loss: 0.4484
# Epoch 219/250
# 300/300 [==============================] - 55s 184ms/step - monet_gen_loss: 3.7311 - photo_gen_loss: 3.5166 - monet_disc_loss: 0.4110 - photo_disc_loss: 0.4296
# Epoch 220/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.3218 - photo_gen_loss: 3.1424 - monet_disc_loss: 0.4855 - photo_disc_loss: 0.5413
# Epoch 221/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.2326 - photo_gen_loss: 3.0130 - monet_disc_loss: 0.4999 - photo_disc_loss: 0.5502
# Epoch 222/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1536 - photo_gen_loss: 2.9516 - monet_disc_loss: 0.5262 - photo_disc_loss: 0.5554
# Epoch 223/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1628 - photo_gen_loss: 2.9871 - monet_disc_loss: 0.5079 - photo_disc_loss: 0.5590
# Epoch 224/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1405 - photo_gen_loss: 2.9639 - monet_disc_loss: 0.5177 - photo_disc_loss: 0.5547
# Epoch 225/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.1714 - photo_gen_loss: 2.9768 - monet_disc_loss: 0.5144 - photo_disc_loss: 0.5638
# Epoch 226/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.1719 - photo_gen_loss: 2.9853 - monet_disc_loss: 0.5118 - photo_disc_loss: 0.5544
# Epoch 227/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.1731 - photo_gen_loss: 2.9640 - monet_disc_loss: 0.4975 - photo_disc_loss: 0.5559
# Epoch 228/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.2466 - photo_gen_loss: 2.9665 - monet_disc_loss: 0.4940 - photo_disc_loss: 0.5618
# Epoch 229/250
# 300/300 [==============================] - 56s 187ms/step - monet_gen_loss: 3.2460 - photo_gen_loss: 2.9961 - monet_disc_loss: 0.4884 - photo_disc_loss: 0.5597
# Epoch 230/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.2909 - photo_gen_loss: 2.9937 - monet_disc_loss: 0.4842 - photo_disc_loss: 0.5742
# Epoch 231/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.4147 - photo_gen_loss: 2.9988 - monet_disc_loss: 0.4385 - photo_disc_loss: 0.5595
# Epoch 232/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.3791 - photo_gen_loss: 3.0033 - monet_disc_loss: 0.4738 - photo_disc_loss: 0.5584
# Epoch 233/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.2693 - photo_gen_loss: 2.9752 - monet_disc_loss: 0.5135 - photo_disc_loss: 0.5711
# Epoch 234/250
# 300/300 [==============================] - 55s 185ms/step - monet_gen_loss: 3.1749 - photo_gen_loss: 2.9760 - monet_disc_loss: 0.5235 - photo_disc_loss: 0.5596
# Epoch 235/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.3408 - photo_gen_loss: 2.9499 - monet_disc_loss: 0.4519 - photo_disc_loss: 0.5664
# Epoch 236/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.3456 - photo_gen_loss: 2.9714 - monet_disc_loss: 0.4753 - photo_disc_loss: 0.5705
# Epoch 237/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.2798 - photo_gen_loss: 2.9740 - monet_disc_loss: 0.4969 - photo_disc_loss: 0.5673
# Epoch 238/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.3357 - photo_gen_loss: 3.0081 - monet_disc_loss: 0.4739 - photo_disc_loss: 0.5634
# Epoch 239/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.2604 - photo_gen_loss: 3.0123 - monet_disc_loss: 0.5145 - photo_disc_loss: 0.5576
# Epoch 240/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.1839 - photo_gen_loss: 2.9426 - monet_disc_loss: 0.5302 - photo_disc_loss: 0.5686
# Epoch 241/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.3497 - photo_gen_loss: 2.9568 - monet_disc_loss: 0.4676 - photo_disc_loss: 0.5708
# Epoch 242/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.3689 - photo_gen_loss: 2.9570 - monet_disc_loss: 0.4682 - photo_disc_loss: 0.5824
# Epoch 243/250
# 300/300 [==============================] - 56s 187ms/step - monet_gen_loss: 3.2849 - photo_gen_loss: 2.9680 - monet_disc_loss: 0.4888 - photo_disc_loss: 0.5674
# Epoch 244/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.4315 - photo_gen_loss: 2.9888 - monet_disc_loss: 0.4490 - photo_disc_loss: 0.5725
# Epoch 245/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.3269 - photo_gen_loss: 2.9681 - monet_disc_loss: 0.4977 - photo_disc_loss: 0.5686
# Epoch 246/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.3371 - photo_gen_loss: 2.9607 - monet_disc_loss: 0.4758 - photo_disc_loss: 0.5779
# Epoch 247/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.4027 - photo_gen_loss: 2.9794 - monet_disc_loss: 0.4692 - photo_disc_loss: 0.5806
# Epoch 248/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.3072 - photo_gen_loss: 2.9680 - monet_disc_loss: 0.4883 - photo_disc_loss: 0.5700
# Epoch 249/250
# 300/300 [==============================] - 56s 185ms/step - monet_gen_loss: 3.4092 - photo_gen_loss: 2.9666 - monet_disc_loss: 0.4561 - photo_disc_loss: 0.5644
# Epoch 250/250
# 300/300 [==============================] - 56s 186ms/step - monet_gen_loss: 3.3904 - photo_gen_loss: 2.9667 - monet_disc_loss: 0.4837 - photo_disc_loss: 0.5657

# %%
#visualizing 
_, ax = plt.subplots(5, 2, figsize=(12, 12))
for i, img in enumerate(photo_ds.take(5)):
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()

# %%
import PIL
! mkdir ../images

# %%
i = 1
for img in photo_ds:
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    im = PIL.Image.fromarray(prediction)
    im.save("../images3/" + str(i) + ".jpg")
    i += 1

# %%
import shutil
shutil.make_archive("/content/drive/MyDrive/images3", 'zip', "/images3")
# Out:
# '/content/drive/MyDrive/images3.zip'

# %%
monet_generator.save('/content/drive/MyDrive/my_modelagain')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/my_modelagain/assets

# %%
from PIL import Image
prediction = monet_generator(, training=False)[0].numpy()
prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
plt.imshow(prediction)

# %%
my_model=keras.models.load_model('/content/drive/MyDrive/my_model.h5')
# Out:
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
